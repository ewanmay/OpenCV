# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
# MATPLOTLIB --> RGB Red, Green, Blue
# OPENCV --> RBG Blue, Green, Red

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('DATA/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
img_gray.max()
# Out:
# 209

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
resized = cv2.resize(fix_img, (1000,400))

# %%
plt.imshow(resized)

# %%
w_ratio = 5/3
h_ratio = 5/3

# %%
new_img = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (650, 975, 3)

# %%
new_img = cv2.flip(fix_img, -1)
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('Totally_new.jpg', fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
